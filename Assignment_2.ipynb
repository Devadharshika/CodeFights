# %% [markdown]
# <a href="https://colab.research.google.com/github/Devadharshika/CodeFights/blob/master/Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
path='/content/drive/MyDrive/House Price India.csv'
dt = pd.read_csv(path)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
data

plt.figure(figsize=(8, 6))
sns.histplot(dt.Price, kde=True)
plt.title('Univariate Analysis: Histogram of Numeric Column')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(dt.Lattitude)
plt.title('Bivariate Analysis: Scatter Plot')
plt.xlabel('Numeric Column 1')
plt.ylabel('Numeric Column 2')
plt.show()

# %%
missing_values = dt.isnull().sum()
data.fillna(dt.mean(), inplace=True)

# %%
dt.describe
# Out:
# <bound method NDFrame.describe of                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %%
sns.pairplot(dt)
plt.title('Multivariate Analysis: Pairplot')
plt.show()
